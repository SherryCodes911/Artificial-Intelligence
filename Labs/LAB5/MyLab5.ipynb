# %%
#Shahriyar Shahid

# %%
import pandas as pd

# %%
df1=pd.DataFrame({"key":[1,2,3,4], "value":['A','B','C','D']})
df2=pd.DataFrame({"key":[1,2,3,4], "value":['E','F','G','H']})
display(df1,df2)
# Out:
#    key value
# 0    1     A
# 1    2     B
# 2    3     C
# 3    4     D
#    key value
# 0    1     E
# 1    2     F
# 2    3     G
# 3    4     H

# %%
df1.columns=('value', 'key')
display(df1)
# Out:
#    value key
# 0      1   A
# 1      2   B
# 2      3   C
# 3      4   D

# %%
df1.drop('value', axis=1, inplace=True)
display(df1)
# Out:
#   key
# 0   A
# 1   B
# 2   C
# 3   D

# %%
df1.drop(1, axis=0, inplace=True)
display(df1)
# Out:
#   key
# 0   A
# 2   C
# 3   D

# %%
concat=pd.concat([df1,df2], ignore_index=True)
concat
# Out:
#    key value
# 0    1     A
# 1    2     B
# 2    3     C
# 3    4     D
# 4    1     E
# 5    2     F
# 6    3     G
# 7    4     H

# %%
import pandas as pd
wine=pd.read_csv("winequality-white.csv", sep=";")
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
wine['quality'].value_counts()
# Out:
# quality
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: count, dtype: int64

# %%
wine['alcohol'].mean()
# Out:
# 10.514267047774602

# %%
wine.loc[(wine['pH']<7)] #acidic
wine.loc[(wine['pH']==7)] #neutral
wine.loc[(wine['pH']>7)] #bacis
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %%
wine['quality'].mean()
# Out:
# 5.87790935075541

# %%
wine['quality'].sort_values(ascending=False) #descending order
# Out:
# 827     9
# 1605    9
# 876     9
# 774     9
# 820     9
#        ..
# 1484    3
# 2373    3
# 251     3
# 1688    3
# 253     3
# Name: quality, Length: 4898, dtype: int64

# %%
wine['quality'].sort_values(ascending=True) #ascending order
wine['quality'].sort_values()
# Out:
# 3307    3
# 445     3
# 2050    3
# 3810    3
# 3409    3
#        ..
# 774     9
# 827     9
# 876     9
# 820     9
# 1605    9
# Name: quality, Length: 4898, dtype: int64

# %%
white=pd.read_csv("winequality-white.csv", sep=";")
red=pd.read_csv("winequality-red.csv", sep=";")
display(white,red)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
concate=pd.concat([white,red], ignore_index=True)
concate
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36            20.7      0.045
# 1               6.3             0.300         0.34             1.6      0.049
# 2               8.1             0.280         0.40             6.9      0.050
# 3               7.2             0.230         0.32             8.5      0.058
# 4               7.2             0.230         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 6492            6.2             0.600         0.08             2.0      0.090
# 6493            5.9             0.550         0.10             2.2      0.062
# 6494            6.3             0.510         0.13             2.3      0.076
# 6495            5.9             0.645         0.12             2.0      0.075
# 6496            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
concate=red+white
display(concate.head(10))
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           14.4              0.97         0.36            22.6      0.121
# 1           14.1              1.18         0.34             4.2      0.147
# 2           15.9              1.04         0.44             9.2      0.142
# 3           18.4              0.51         0.88            10.4      0.133
# 4           14.6              0.93         0.32            10.4      0.134
# 5           15.5              0.94         0.40             8.7      0.125
# 6           14.1              0.92         0.22             8.6      0.114
# 7           14.3              0.92         0.36            21.9      0.110
# 8           14.1              0.88         0.36             3.6      0.122
# 9           15.6              0.72         0.79             7.6      0.115
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...
