# %%
from sklearn import datasets
from sklearn.svm import SVC
from sklearn.inspection import DecisionBoundaryDisplay
import matplotlib.pyplot as plt

# %%
iris=datasets.load_iris()
X=iris.data[:, :2]
y=iris.target
display(X.shape, y.shape)
# Out:
# (150, 2)
# (150,)

# %%
svm=SVC()
svm.fit(X,y)
# Out:
# SVC()

# %%
DecisionBoundaryDisplay.from_estimator(
    svm, X, response_method="predict",alpha=0.8, cmap=plt.cm.Spectral, xlabel=iris.feature_names[0], ylabel=iris.feature_names[1]
)

# %%
plt.scatter(X[:, 0], X[:,1], c=y, s=20, edgecolors="k")
plt.show()

# %%
from sklearn.datasets import load_iris
from sklearn.svm import SVC
from sklearn.inspection import DecisionBoundaryDisplay
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split as tts
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
data=load_iris()
X=data.data[:, :2]
y=data.target

# %%
X_train,X_test, y_train, y_test=tts(X,y, random_state=42, test_size=0.2)
X_train.shape,X_test.shape, y_train.shape, y_test.shape
# Out:
# ((120, 2), (30, 2), (120,), (30,))

# %%
svm=SVC()
svm.fit(X,y)
# Out:
# SVC()

# %%
pred=svm.predict(X_test)
pred
# Out:
# array([1, 0, 2, 1, 2, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 2, 2, 1, 1, 2, 0, 1,
#        0, 2, 2, 2, 2, 2, 0, 0])

# %%
acc=accuracy_score(y_test, pred)
acc
# Out:
# 0.9

# %%
DecisionBoundaryDisplay.from_estimator(
        svm, X, response_method="predict", alpha=0.8, cmap=plt.cm.Spectral
)
